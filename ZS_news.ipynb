# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train = pd.read_csv('/content/drive/My Drive/ZS/dataset/train_file.csv')

# %%
test = pd.read_csv('/content/drive/My Drive/ZS/dataset/test_file.csv')

# %%
sample = pd.read_csv('/content/drive/My Drive/ZS/dataset/sample_submission.csv')

# %%
train.head().T
# Out:
#                                                                    0  ...                                                  4
# IDLink                                                    Tr3CMgRv1N  ...                                         wUbnxgvqaZ
# Title               Obama Lays Wreath at Arlington National Cemetery  ...  Tourism, govt spending buoys Thai economy in J...
# Headline           Obama Lays Wreath at Arlington National Cemete...  ...  Tourism and public spending continued to boost...
# Source                                                     USA TODAY  ...           The Nation - Thailand&#39;s English news
# Topic                                                          obama  ...                                            economy
# PublishDate                                      2002-04-02 00:00:00  ...                                2015-03-01 00:11:00
# ...

# %%
train.shape
# Out:
# (55932, 11)

# %%
test.shape
# Out:
# (37288, 9)

# %%
train.GooglePlus.value_counts().head(50)

# %%
train[train.GooglePlus<10].GooglePlus.hist()

# %%
train.dtypes
# Out:
# IDLink                object
# Title                 object
# Headline              object
# Source                object
# Topic                 object
# PublishDate           object
# Facebook               int64
# GooglePlus             int64
# LinkedIn               int64
# SentimentTitle       float64
# SentimentHeadline    float64
# dtype: object

# %%
plt.scatter(train.SentimentHeadline, train.SentimentTitle)

# %%
sns.scatterplot(train.SentimentHeadline,train.SentimentTitle,train.Topic)

# %%
train.SentimentHeadline.corr(train.SentimentTitle)
# Out:
# 0.18558396451115228

# %%
plt.scatter(train.Facebook, train.SentimentHeadline)

# %%
sns.heatmap(train.corr())

# %%
plt.scatter(train.Facebook, train.SentimentHeadline_abs)

# %%
train['SentimentHeadline_abs'] = train.SentimentHeadline.abs()

# %%
train['SentimentTitle_abs'] = train.SentimentTitle.abs()

# %%
train.head().T
# Out:
#                                                                        0  ...                                                  4
# IDLink                                                        Tr3CMgRv1N  ...                                         wUbnxgvqaZ
# Title                   Obama Lays Wreath at Arlington National Cemetery  ...  Tourism, govt spending buoys Thai economy in J...
# Headline               Obama Lays Wreath at Arlington National Cemete...  ...  Tourism and public spending continued to boost...
# Source                                                         USA TODAY  ...           The Nation - Thailand&#39;s English news
# Topic                                                              obama  ...                                            economy
# PublishDate                                          2002-04-02 00:00:00  ...                                2015-03-01 00:11:00
# ...

# %%
sns.heatmap(train.corr())

# %%
train.SentimentHeadline.hist()

# %%
train.SentimentTitle.hist()

# %%
train.describe().T
# Out:
#                          count        mean  ...        75%           max
# Facebook               55932.0  132.050329  ...  37.000000  49211.000000
# GooglePlus             55932.0    4.551616  ...   2.000000   1267.000000
# LinkedIn               55932.0   14.300132  ...   4.000000   3716.000000
# SentimentTitle         55932.0   -0.006318  ...   0.063969      0.962354
# SentimentHeadline      55932.0   -0.029577  ...   0.057354      0.964646
# SentimentHeadline_abs  55932.0    0.112216  ...   0.159901      0.964646
# SentimentTitle_abs     55932.0    0.096589  ...   0.144338      0.962354
#
# [7 rows x 8 columns]

# %%
train.Title.str.len().corr(train.SentimentTitle)
# Out:
# -0.008299716901151954

# %% [markdown]
# Title - No of chars vs sentiment

# %%
plt.scatter(train.Title.str.len(),train.SentimentTitle_abs)

# %%
sns.scatterplot(train.Headline.str.len(),train.SentimentHeadline_abs,train.Topic)

# %%
plt.scatter(train.Title.str.len(),train.Headline.str.len())

# %%
(train.Title.str.len()>125).sum()
# Out:
# 2

# %%
plt.scatter(test.Title.str.len(),test.Headline.str.len())

# %% [markdown]
# WORD COUNT

# %%
train.Title.str.count(' ').hist()

# %%
plt.scatter(train.Title.str.count(' '),train.Headline.str.count(' '))

# %%
pip install gensim

# %%
import gensim

# %%
from gensim.models.word2vec import Word2Vec
